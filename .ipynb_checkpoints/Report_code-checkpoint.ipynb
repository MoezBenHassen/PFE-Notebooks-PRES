# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
df_ta = pd.read_json('C:\\Users\\SBS\IMPORTED_DATA\\ta.json')

# %%
df_ta
# Out:
#                                          _id  interRSI  interBollingerBands  \
# 0       {'$oid': '61fe0c065e2f1c1a60016390'}         0                    0
# 1       {'$oid': '61fe0c065e2f1c1a60016395'}         0                    0
# 2       {'$oid': '61fe0c065e2f1c1a6001639a'}         0                    0
# 3       {'$oid': '61fe0c065e2f1c1a6001639f'}         0                    0
# 4       {'$oid': '61fe0c065e2f1c1a60016392'}         0                    0
# ...                                      ...       ...                  ...
# 140333  {'$oid': '61fe0c2e5e2f1c1a600387bd'}         1                    1
# 140334  {'$oid': '61fe0c2e5e2f1c1a600387be'}         1                    0
# 140335  {'$oid': '61fe0c2e5e2f1c1a600387bf'}         0                    0
# 140336  {'$oid': '61fe0c2e5e2f1c1a600387c0'}         0                    1
# 140337  {'$oid': '61fe0c2e5e2f1c1a600387c1'}         0                    1
#
#         interROC  interMACD  interMOM                             ADL  price  \
# 0              0          0         0                         1350000  55.50
# 1              0          0         0                         1580599  62.50
# 2              0          0         0                         1582877  62.84
# 3             -1          0        -1                         1585797  62.30
# 4              0          0         0                         1580176  57.50
# ...          ...        ...       ...                             ...    ...
# 140333         0          0        -1  {'$numberDouble': '-Infinity'}   0.83
# 140334         0          0         0  {'$numberDouble': '-Infinity'}   1.05
# 140335         0          0         0  {'$numberDouble': '-Infinity'}   1.23
# 140336         0          0         0  {'$numberDouble': '-Infinity'}   1.28
# 140337         0          0         0  {'$numberDouble': '-Infinity'}   1.38
#
#              instrument       date       WEMA        OBV    RSI        ROC  \
# 0       ASSUR MAGHREBIA 2020-12-29        NaN        NaN    NaN        NaN
# 1       ASSUR MAGHREBIA 2022-01-10  59.772000   253847.0    NaN        NaN
# 2       ASSUR MAGHREBIA 2022-01-17  61.625449   255718.0    NaN        NaN
# 3       ASSUR MAGHREBIA 2022-01-28  62.005491   254510.0  66.75  -0.240192
# 4       ASSUR MAGHREBIA 2020-12-31        NaN   254078.0    NaN        NaN
# ...                 ...        ...        ...        ...    ...        ...
# 140333         SERVICOM 2022-01-17   1.766754  6150298.0  14.86 -58.500000
# 140334         SERVICOM 2022-01-25   1.623403  6214436.0  25.34 -48.019802
# 140335         SERVICOM 2022-01-31   1.544723  6250366.0  32.64 -41.148325
# 140336         SERVICOM 2022-02-01   1.491778  6282109.0  34.56 -39.906103
# 140337         SERVICOM 2022-02-03   1.469422  6361345.0  38.33 -34.285714
#
#                                                       MOM       ATR  \
# 0                                                     NaN       NaN
# 1                                                     NaN       NaN
# 2                                                     NaN       NaN
# 3       {'MOM': -1.200000000000002, 'EmaMOM': -0.01946...  1.968316
# 4                                                     NaN       NaN
# ...                                                   ...       ...
# 140333       {'MOM': -1.19, 'EmaMOM': -0.651370803372138}  0.120654
# 140334  {'MOM': -1.039999999999999, 'EmaMOM': -0.60911...  0.127750
# 140335  {'MOM': -0.899999999999999, 'EmaMOM': -0.55081...  0.131483
# 140336  {'MOM': -0.8200000000000001, 'EmaMOM': -0.5191...  0.125662
# 140337     {'MOM': -0.71, 'EmaMOM': -0.45841894331582106}  0.123829
#
#                                                Stochastic   WilliamsR  \
# 0                                                     NaN         NaN
# 1                                                     NaN         NaN
# 2                                                     NaN         NaN
# 3        {'k': 75.23510971786827, 'd': 80.02271409880136}  -24.764890
# 4                                                     NaN         NaN
# ...                                                   ...         ...
# 140333                  {'k': 0, 'd': 26.086956521739193} -100.000000
# 140334  {'k': 16.923076923076934, 'd': 20.133779264214...  -83.076923
# 140335  {'k': 30.769230769230777, 'd': 15.89743589743594}  -69.230769
# 140336  {'k': 34.61538461538463, 'd': 27.435897435897484}  -65.384615
# 140337   {'k': 42.30769230769231, 'd': 35.89743589743594}  -57.692308
#
#                                            BollingerBands  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 140333  {'middle': 1.9774999999999872, 'upper': 2.5208...
# 140334  {'middle': 1.925499999999987, 'upper': 2.59924...
# 140335  {'middle': 1.879499999999987, 'upper': 2.60897...
# 140336  {'middle': 1.8364999999999871, 'upper': 2.6000...
# 140337  {'middle': 1.802999999999987, 'upper': 2.58474...
#
#                                                      MACD
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 140333  {'MACD': -0.10164524055147801, 'signal': -0.01...
# 140334  {'MACD': -0.156092200123417, 'signal': -0.0451...
# 140335  {'MACD': -0.182612271581506, 'signal': -0.0726...
# 140336  {'MACD': -0.19732044982836802, 'signal': -0.09...
# 140337  {'MACD': -0.19861807723171102, 'signal': -0.11...
#
# [140338 rows x 20 columns]

# %%
df_ta.shape
# Out:
# (140338, 20)

# %%
df_ta.dtypes.value_counts()
# Out:
# object            7
# float64           7
# int64             5
# datetime64[ns]    1
# dtype: int64

# %%
#define data
data = [5, 7, 7, 1]
labels = ['int64', 'float64', 'object', 'datetime64']

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:4]

#create pie chart
sns.set(rc = {'figure.figsize':(15,10)})
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
# Out:
# object            7
# float64           7
# int64             5
# datetime64[ns]    1
# dtype: int64
