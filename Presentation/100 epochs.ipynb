# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading ta.json into a dataframe

# %%
df_ta = pd.read_json('ta.json')
#df_ta.head(50)
df_ta
#df_ta.to_excel("df_ta.xlsx")
# Out:
#                                          _id  interRSI  interBollingerBands  \
# 0       {'$oid': '61fe0c065e2f1c1a60016390'}         0                    0
# 1       {'$oid': '61fe0c065e2f1c1a60016395'}         0                    0
# 2       {'$oid': '61fe0c065e2f1c1a6001639a'}         0                    0
# 3       {'$oid': '61fe0c065e2f1c1a6001639f'}         0                    0
# 4       {'$oid': '61fe0c065e2f1c1a60016392'}         0                    0
# ...                                      ...       ...                  ...
# 140333  {'$oid': '61fe0c2e5e2f1c1a600387bd'}         1                    1
# 140334  {'$oid': '61fe0c2e5e2f1c1a600387be'}         1                    0
# 140335  {'$oid': '61fe0c2e5e2f1c1a600387bf'}         0                    0
# 140336  {'$oid': '61fe0c2e5e2f1c1a600387c0'}         0                    1
# 140337  {'$oid': '61fe0c2e5e2f1c1a600387c1'}         0                    1
#
#         interROC  interMACD  interMOM                             ADL  price  \
# 0              0          0         0                         1350000  55.50
# 1              0          0         0                         1580599  62.50
# 2              0          0         0                         1582877  62.84
# 3             -1          0        -1                         1585797  62.30
# 4              0          0         0                         1580176  57.50
# ...          ...        ...       ...                             ...    ...
# 140333         0          0        -1  {'$numberDouble': '-Infinity'}   0.83
# 140334         0          0         0  {'$numberDouble': '-Infinity'}   1.05
# 140335         0          0         0  {'$numberDouble': '-Infinity'}   1.23
# 140336         0          0         0  {'$numberDouble': '-Infinity'}   1.28
# 140337         0          0         0  {'$numberDouble': '-Infinity'}   1.38
#
#              instrument       date       WEMA        OBV    RSI        ROC  \
# 0       ASSUR MAGHREBIA 2020-12-29        NaN        NaN    NaN        NaN
# 1       ASSUR MAGHREBIA 2022-01-10  59.772000   253847.0    NaN        NaN
# 2       ASSUR MAGHREBIA 2022-01-17  61.625449   255718.0    NaN        NaN
# 3       ASSUR MAGHREBIA 2022-01-28  62.005491   254510.0  66.75  -0.240192
# 4       ASSUR MAGHREBIA 2020-12-31        NaN   254078.0    NaN        NaN
# ...                 ...        ...        ...        ...    ...        ...
# 140333         SERVICOM 2022-01-17   1.766754  6150298.0  14.86 -58.500000
# 140334         SERVICOM 2022-01-25   1.623403  6214436.0  25.34 -48.019802
# 140335         SERVICOM 2022-01-31   1.544723  6250366.0  32.64 -41.148325
# 140336         SERVICOM 2022-02-01   1.491778  6282109.0  34.56 -39.906103
# 140337         SERVICOM 2022-02-03   1.469422  6361345.0  38.33 -34.285714
#
#                                                       MOM       ATR  \
# 0                                                     NaN       NaN
# 1                                                     NaN       NaN
# 2                                                     NaN       NaN
# 3       {'MOM': -1.200000000000002, 'EmaMOM': -0.01946...  1.968316
# 4                                                     NaN       NaN
# ...                                                   ...       ...
# 140333       {'MOM': -1.19, 'EmaMOM': -0.651370803372138}  0.120654
# 140334  {'MOM': -1.039999999999999, 'EmaMOM': -0.60911...  0.127750
# 140335  {'MOM': -0.899999999999999, 'EmaMOM': -0.55081...  0.131483
# 140336  {'MOM': -0.8200000000000001, 'EmaMOM': -0.5191...  0.125662
# 140337     {'MOM': -0.71, 'EmaMOM': -0.45841894331582106}  0.123829
#
#                                                Stochastic   WilliamsR  \
# 0                                                     NaN         NaN
# 1                                                     NaN         NaN
# 2                                                     NaN         NaN
# 3        {'k': 75.23510971786827, 'd': 80.02271409880136}  -24.764890
# 4                                                     NaN         NaN
# ...                                                   ...         ...
# 140333                  {'k': 0, 'd': 26.086956521739193} -100.000000
# 140334  {'k': 16.923076923076934, 'd': 20.133779264214...  -83.076923
# 140335  {'k': 30.769230769230777, 'd': 15.89743589743594}  -69.230769
# 140336  {'k': 34.61538461538463, 'd': 27.435897435897484}  -65.384615
# 140337   {'k': 42.30769230769231, 'd': 35.89743589743594}  -57.692308
#
#                                            BollingerBands  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 140333  {'middle': 1.9774999999999872, 'upper': 2.5208...
# 140334  {'middle': 1.925499999999987, 'upper': 2.59924...
# 140335  {'middle': 1.879499999999987, 'upper': 2.60897...
# 140336  {'middle': 1.8364999999999871, 'upper': 2.6000...
# 140337  {'middle': 1.802999999999987, 'upper': 2.58474...
#
#                                                      MACD
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 140333  {'MACD': -0.10164524055147801, 'signal': -0.01...
# 140334  {'MACD': -0.156092200123417, 'signal': -0.0451...
# 140335  {'MACD': -0.182612271581506, 'signal': -0.0726...
# 140336  {'MACD': -0.19732044982836802, 'signal': -0.09...
# 140337  {'MACD': -0.19861807723171102, 'signal': -0.11...
#
# [140338 rows x 20 columns]

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ### Dataframe shape (Dimensions)

# %%
df_ta.shape
# Out:
# (140338, 20)

# %% [markdown]
# ### DATA TYPES inside df_ta

# %% [markdown]
# #### We look for all the data types inside our dataframe and they numbers accordingly

# %%
df_ta.dtypes.value_counts()
# Out:
# object            7
# float64           7
# int64             5
# datetime64[ns]    1
# dtype: int64

# %% [markdown]
# #### Plotting results

# %%
#define data
data = [5, 7, 7, 1]
labels = ['int64', 'float64', 'object', 'datetime64']

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:4]

#create pie chart
sns.set(rc = {'figure.figsize':(15,10)})
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# ### Check all instruments available from the Tunisian Stock market & their total number

# %%
all_instruments = df_ta['instrument'].unique()
print(all_instruments)
# Out:
# ['ASSUR MAGHREBIA' 'AIR LIQUDE TSIE' 'ARTES' 'ELECTROSTAR' 'SOPAT'
#  'ALKIMIA' 'BEST LEASE' 'HANNIBAL LEASE' 'SOTUMAG' 'BH' 'MPBS'
#  'TAWASOL GP HOLDING' 'ATELIER MEUBLE INT' 'ICF' 'SOTUVER' 'AMEN BANK'
#  'MONOPRIX' 'STIP' 'BT' 'POULINA GP HOLDING' 'TUNISAIR' 'BTE (ADP)' 'SAH'
#  'TUNISIE LEASING' 'AETECH' 'ASSAD' 'CEREALIS' 'SFBT' 'UIB'
#  'ENNAKL AUTOMOBILES' 'SOTEMAIL' 'ESSOUKNA' 'SOTETEL' 'ADWYA' 'AMS' 'BNA'
#  'PLAC. TSIE-SICAF' 'TUNIS RE' 'CIL' 'SIAME' 'UNIMED' 'CIMENTS DE BIZERTE'
#  'SIMPAR' 'BH ASSURANCE' 'NEW BODY LINE' 'TELNET HOLDING' 'DELICE HOLDING'
#  'SOMOCER' 'CITY CARS' 'SITS' 'ATL' 'GIF-FILTER' 'SOTRAPIL' 'ASTREE'
#  'EURO-CYCLES' 'SOTIPAPIER' 'BIAT' 'ONE TECH HOLDING' 'TUNINVEST-SICAR'
#  'BH LEASING' 'OFFICEPLAST' 'TPR' 'WIFACK INT BANK' 'ATTIJARI LEASING'
#  'MAGHREB INTERN PUB' 'STB' 'ATTIJARI BANK' 'MAGASIN GENERAL' 'STAR' 'ATB'
#  'LAND OR' 'SPDIT - SICAF' 'CELLCOM' 'SERVICOM' 'UBCI' 'CARTHAGE CEMENT'
#  'SANIMED' 'UADH']

# %%
nbr = len(all_instruments)
print ("Total nbr of instruments = ", nbr)
# Out:
# Total nbr of instruments =  78

# %% [markdown]
# ### Checking the Number of rows available for a selected instrument

# %%
#datetime import for datime64 datatype
from datetime import datetime

# %%
instru = "ADWYA"
df2=df_ta.loc[df_ta['instrument'] == instru]
YEAR =[]
nb_r =[]
for i in range(10):
    lastTradingData = df2[(df_ta['date'] >= datetime(2012+i,1,1)) & (df2['date'] <= datetime(2012+i,12,31))]
    YEAR.append(2012+i)
    nb_r.append(len(lastTradingData))
# Out:
# C:\Users\SBS\AppData\Local\Temp/ipykernel_17016/2766693794.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   lastTradingData = df2[(df_ta['date'] >= datetime(2012+i,1,1)) & (df2['date'] <= datetime(2012+i,12,31))]

# %% [markdown]
# #### We check the overall Years

# %%
print("YEARS = ",YEAR)
# Out:
# YEARS =  [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %% [markdown]
# #### We check the number of rows for each found year for the instrument "ADWYA"

# %%
print('For each year ==> the number of rows for " ', instru, ' "')
print(YEAR)
print(nb_r)
# Out:
# For each year ==> the number of rows for "  ADWYA  "
# [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# [250, 245, 247, 240, 245, 249, 248, 242, 247, 219]

# %% [markdown]
# ### Comparing number of data availble (rows) throughout the years 2012 --> 2021

# %%
#YEAR = ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
nb_y=0
nbb =[]
yearIndex = 1
df_nbRows_YEARS = pd.DataFrame(columns = ['Year', 'nb'])

for year_i in YEAR:
    current_year = year_i
    for j in df_ta['date']: 
        #dd = datetime.strptime(str(j), '%Y-%m-%d %H:%M:%S') 
        if ( j.year == current_year):
            nb_y= nb_y+1
    print('NUMBER OF NB ROWS  FOR YEAR ', year_i, '= ',nb_y)
    
    nbb.append(str(year_i))
    nbb.append(nb_y)
    df_nbRows_YEARS.loc[yearIndex]=nbb
    nb_y=0
    yearIndex+=1
    nbb=[]
# Out:
# NUMBER OF NB ROWS  FOR YEAR  2012 =  11635
# NUMBER OF NB ROWS  FOR YEAR  2013 =  12016
# NUMBER OF NB ROWS  FOR YEAR  2014 =  13924
# NUMBER OF NB ROWS  FOR YEAR  2015 =  14754
# NUMBER OF NB ROWS  FOR YEAR  2016 =  15174
# NUMBER OF NB ROWS  FOR YEAR  2017 =  14952
# NUMBER OF NB ROWS  FOR YEAR  2018 =  15212
# NUMBER OF NB ROWS  FOR YEAR  2019 =  14206
# NUMBER OF NB ROWS  FOR YEAR  2020 =  14415
# NUMBER OF NB ROWS  FOR YEAR  2021 =  12768

# %%
#verify df_nbRows_YEARS before plotting
df_nbRows_YEARS
# Out:
#     Year     nb
# 1   2012  11635
# 2   2013  12016
# 3   2014  13924
# 4   2015  14754
# 5   2016  15174
# 6   2017  14952
# 7   2018  15212
# 8   2019  14206
# 9   2020  14415
# 10  2021  12768

# %% [markdown]
# #### Plotting Results

# %%
#define data
data = [11635, 12016, 13924, 14754, 15174, 14952, 15212, 14206, 14415, 12768]
labels = ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

fig = plt.figure(figsize = (15, 10))
 
# creating the bar plot
plt.bar(labels, data, color ='maroon', width = 0.7)
 
plt.xlabel("Years")
plt.ylabel("Nb of rows")
plt.title("Nb of rows per year")
plt.show()

# %% [markdown]
# ### Comparing the data volume of each instrument for all years (2012 -> 2021)

# %% [markdown]
# #### Transfer our instruments into a list

# %%
stocks = ['ASSUR MAGHREBIA', 'AIR LIQUDE TSIE', 'ARTES', 'ELECTROSTAR', 'SOPAT', 'ALKIMIA','BEST LEASE', 'HANNIBAL LEASE' ,'SOTUMAG', 'BH' ,'MPBS','TAWASOL GP HOLDING', 'ATELIER MEUBLE INT', 'ICF', 
'SOTUVER' ,'AMEN BANK', 'MONOPRIX' ,'STIP', 'BT' ,'POULINA GP HOLDING' ,'TUNISAIR', 'BTE (ADP)', 'SAH', 'TUNISIE LEASING' ,'AETECH', 'ASSAD', 'CEREALIS', 'SFBT', 'UIB',
 'ENNAKL AUTOMOBILES' ,'SOTEMAIL', 'ESSOUKNA', 'SOTETEL', 'ADWYA' ,'AMS' ,'BNA', 'PLAC. TSIE-SICAF', 'TUNIS RE', 'CIL', 'SIAME', 'UNIMED' ,'CIMENTS DE BIZERTE', 'SIMPAR' ,
 'BH ASSURANCE' ,'NEW BODY LINE' ,'TELNET HOLDING' ,'DELICE HOLDING', 'SOMOCER', 'CITY CARS' ,'SITS' ,'ATL' ,'GIF-FILTER', 'SOTRAPIL' ,'ASTREE', 'EURO-CYCLES', 'SOTIPAPIER' ,
 'BIAT', 'ONE TECH HOLDING' ,'TUNINVEST-SICAR', 'BH LEASING', 'OFFICEPLAST', 'TPR','WIFACK INT BANK' ,'ATTIJARI LEASING', 'MAGHREB INTERN PUB', 'STB', 'ATTIJARI BANK', 'MAGASIN GENERAL',
  'STAR','ATB', 'LAND OR', 'SPDIT - SICAF', 'CELLCOM' ,'SERVICOM' ,'UBCI' ,'CARTHAGE CEMENT', 'SANIMED', 'UADH']

# %% [markdown]
# #### Get the entire instrument row of df_ta (df_ta['instrument']) and put them into a list

# %%
li_instrument = []
li_instrument = list( df_ta['instrument'])
print(li_instrument)
# Out:
# ['ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'ASSUR MAGHREBIA', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQUDE TSIE', 'AIR LIQU ...

# %% [markdown]
# #### Calc the number of entries for each instrument

# %%
nbRows_stock_i = 0
nbRows_perStock = pd.DataFrame(columns = ['Instrument', 'nbr de lignes'])

nbb = []
index = 1

def search(list, platform):
    count=0
    for i in range(len(li_instrument)):
        if list[i] == platform:
            count=count+1
    return count
for i in stocks:
    nbRows_stock_i = search(li_instrument, i)
    print(i , '=', nbRows_stock_i)
    nbb.append(str(i))
    nbb.append(nbRows_stock_i)

    nbRows_perStock.loc[index]=nbb
    index=index+1
    nbb=[]
# Out:
# ASSUR MAGHREBIA = 20
# AIR LIQUDE TSIE = 1625
# ARTES = 2441
# ELECTROSTAR = 2216
# SOPAT = 2323
# ALKIMIA = 862
# BEST LEASE = 784
# HANNIBAL LEASE = 1086
# SOTUMAG = 2372
# BH = 2171
# MPBS = 1848
# TAWASOL GP HOLDING = 1772
# ATELIER MEUBLE INT = 1145
# ICF = 1713
# SOTUVER = 2498
# AMEN BANK = 2469
# MONOPRIX = 2400
# STIP = 664
# BT = 2490
# POULINA GP HOLDING = 2389
# TUNISAIR = 2451
# BTE (ADP) = 1586
# SAH = 1985
# TUNISIE LEASING = 1435
# AETECH = 1502
# ASSAD = 2471
# CEREALIS = 1359
# SFBT = 2502
# UIB = 2461
# ENNAKL AUTOMOBILES = 2438
# SOTEMAIL = 1035
# ESSOUKNA = 2059
# SOTETEL = 2437
# ADWYA = 2453
# AMS = 2226
# BNA = 2423
# PLAC. TSIE-SICAF = 187
# TUNIS RE = 2268
# CIL = 1722
# SIAME = 2355
# UNIMED = 1395
# CIMENTS DE BIZERTE = 1839
# SIMPAR = 1594
# BH ASSURANCE = 177
# NEW BODY LINE = 1959
# TELNET HOLDING = 2481
# DELICE HOLDING = 1693
# SOMOCER = 2498
# CITY CARS = 1875
# SITS = 1912
# ATL = 2317
# GIF-FILTER = 2358
# SOTRAPIL = 2288
# ASTREE = 435
# EURO-CYCLES = 2129
# SOTIPAPIER = 1896
# BIAT = 2464
# ONE TECH HOLDING = 2079
# TUNINVEST-SICAR = 1168
# BH LEASING = 232
# OFFICEPLAST = 1193
# TPR = 2494
# WIFACK INT BANK = 864
# ATTIJARI LEASING = 1740
# MAGHREB INTERN PUB = 469
# STB = 2393
# ATTIJARI BANK = 2498
# MAGASIN GENERAL = 1732
# STAR = 1922
# ATB = 2370
# LAND OR = 1931
# SPDIT - SICAF = 1675
# CELLCOM = 1634
# SERVICOM = 2284
# UBCI = 1263
# CARTHAGE CEMENT = 2439
# SANIMED = 531
# UADH = 1474

# %%
nbRows_perStock
#nbRows_perStock.to_json('Nbr_Rows_Per_Stock.json')
#nbRows_perStock.to_excel("Nbr_Rows_Per_Stock.xlsx")
# Out:
#          Instrument nbr de lignes
# 1   ASSUR MAGHREBIA            20
# 2   AIR LIQUDE TSIE          1625
# 3             ARTES          2441
# 4       ELECTROSTAR          2216
# 5             SOPAT          2323
# ..              ...           ...
# 74         SERVICOM          2284
# 75             UBCI          1263
# 76  CARTHAGE CEMENT          2439
# 77          SANIMED           531
# 78             UADH          1474
#
# [78 rows x 2 columns]

# %% [markdown]
# #### Plot the above result

# %%
#define data
sns.barplot(x = 'Instrument', y = 'nbr de lignes', data = nbRows_perStock)
plt.xticks(rotation=90)
plt.xlabel("Instrument", size=20)
plt.ylabel("Nbre de lignes", size=20)
# Show the plot
plt.show()

# %% [markdown]
# # DATA PREPERATION

# %% [markdown]
# ### Loading price of a specific instrument into a dataframe (df_price)

# %%
new_df_ta = df_ta[['instrument', 'price', 'date', 'RSI', 'ROC']].copy()

# %%
#new_df_ta
new_df_ta #.head(60)
#new.shape
# Out:
#              instrument  price       date    RSI        ROC
# 0       ASSUR MAGHREBIA  55.50 2020-12-29    NaN        NaN
# 1       ASSUR MAGHREBIA  62.50 2022-01-10    NaN        NaN
# 2       ASSUR MAGHREBIA  62.84 2022-01-17    NaN        NaN
# 3       ASSUR MAGHREBIA  62.30 2022-01-28  66.75  -0.240192
# 4       ASSUR MAGHREBIA  57.50 2020-12-31    NaN        NaN
# ...                 ...    ...        ...    ...        ...
# 140333         SERVICOM   0.83 2022-01-17  14.86 -58.500000
# 140334         SERVICOM   1.05 2022-01-25  25.34 -48.019802
# 140335         SERVICOM   1.23 2022-01-31  32.64 -41.148325
# 140336         SERVICOM   1.28 2022-02-01  34.56 -39.906103
# 140337         SERVICOM   1.38 2022-02-03  38.33 -34.285714
#
# [140338 rows x 5 columns]

# %%
instru = "SERVICOM"
df_instrument = new_df_ta.loc[ new_df_ta['instrument'] == instru]
df_instrument.reset_index(drop=True)
# Out:
#      instrument   price       date    RSI        ROC
# 0      SERVICOM  11.299 2012-01-02    NaN        NaN
# 1      SERVICOM  11.229 2012-01-03    NaN        NaN
# 2      SERVICOM  11.469 2012-01-04    NaN        NaN
# 3      SERVICOM  11.369 2012-01-05    NaN        NaN
# 4      SERVICOM  11.519 2012-01-06    NaN        NaN
# ...         ...     ...        ...    ...        ...
# 2279   SERVICOM   0.830 2022-01-17  14.86 -58.500000
# 2280   SERVICOM   1.050 2022-01-25  25.34 -48.019802
# 2281   SERVICOM   1.230 2022-01-31  32.64 -41.148325
# 2282   SERVICOM   1.280 2022-02-01  34.56 -39.906103
# 2283   SERVICOM   1.380 2022-02-03  38.33 -34.285714
#
# [2284 rows x 5 columns]

# %%
sns.set_style('ticks')
plt.figure(figsize=(30,10))
#plt.rcParams["axes.labelsize"] = 30
sns.lineplot(data=df_instrument,x="date", y="price", palette="tab10", linewidth=2.5)
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("Date",size=30)
YLABEL = instru + " Price"
plt.ylabel(YLABEL,size=30)
plt.show()

# %%
df_price0 = pd.DataFrame(df_ta['price'].loc[df_ta['instrument'] == instru]).reset_index(drop=True)
df_price0.shape
# Out:
# (2284, 1)

# %%
df_price0.shape[0]
#df_price
# Out:
# 2284

# %%
df_price0
# Out:
#        price
# 0     11.299
# 1     11.229
# 2     11.469
# 3     11.369
# 4     11.519
# ...      ...
# 2279   0.830
# 2280   1.050
# 2281   1.230
# 2282   1.280
# 2283   1.380
#
# [2284 rows x 1 columns]

# %% [markdown]
# ### LSTM ARE SENSITIVE TO DATA SCALE ==> apply MinMaxScaler to scale the data accordingly

# %%
#import lib for scaling
from sklearn.preprocessing import MinMaxScaler

# %%
#scaler=MinMaxScaler(feature_range=(0,1))
#df_price = scaler.fit_transform(np.array(df_price).reshape(-1,1))
fig, ax = plt.subplots(1,2, figsize=(20,10))
sns.set_style('ticks')
graph= sns.histplot(df_price0,kde='True', ax=ax[0])
ax[0].set_title("Original Data")
graph.set_xlabel("Prix", fontsize = 20)
graph.set_ylabel("Count", fontsize = 15)

scaler=MinMaxScaler(feature_range=(0,1))
df_price = scaler.fit_transform(np.array(df_price0).reshape(-1,1))
graph2=sns.histplot(df_price, kde='True', ax=ax[1])

graph2.set_xlabel("Prix", fontsize = 20)
graph2.set_ylabel("Count", fontsize = 15)
ax[0].set_title("Original Data", fontsize= 20)
ax[1].set_title("Scaled Data", fontsize= 20)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
print("Price after scale : ",df_price)
# Out:
# Price after scale :  [[0.40664664]
#  [0.40401802]
#  [0.41303042]
#  ...
#  [0.02853924]
#  [0.03041682]
#  [0.03417199]]

# %% [markdown]
# ### Splitting Dataset into a Train / Test split

# %%
# 65% (0.65) of dataframe being training size
training_size = int(len(df_price)*0.65)

#the rest assigned to test size 
test_size = len(df_price)-training_size 

train_data,test_data=df_price[0:training_size,:],df_price[training_size:len(df_price),:1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14260/1941986557.py in <module>
#       1 # 65% (0.65) of dataframe being training size
# ----> 2 training_size = int(len(df_price)*0.65)
#       3
#       4 #the rest assigned to test size
#       5 test_size = len(df_price)-training_size
#
# NameError: name 'df_price' is not defined

# %%
print("train size = ",training_size, "       || test size = ", test_size)
print("length train_data = ", len(train_data), "|| length test_data = ", len(test_data))

# %% [markdown]
# ### DATA PREPROCESSING -- Creating Dataset matrix from train / test arrays previously created and reshaping them accordingly to a timestep standard (100 days)

# %%
#convert array of values into a dataset matrix

def create_dataset(dataset,time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i + time_step), 0] 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

from sklearn.model_selection import train_test_split

# %%
# reshape into X=t, t+3, t+2, ... and Y=t+4
time_step = 100
X_train, Y_train = create_dataset(train_data, time_step)
X_test, Y_test = create_dataset(test_data, time_step)

Y_train
# Out:
# array([0.43251971, 0.44337214, 0.44074352, ..., 0.00713481, 0.00638378,
#        0.00638378])

# %% [markdown]
# ##### verify shapes train test

# %%
print("========= TRAIN SPLIT =========")
print("X_train .shape = ",X_train.shape)
print("Y_train .shape = ",Y_train.shape)
# Out:
# ========= TRAIN SPLIT =========
# X_train .shape =  (1726, 100)
# Y_train .shape =  (1726,)

# %%
print("========= TEST SPLIT =========")
print("X_test .shape = ", X_test.shape)
print("Y_test .shape = ", Y_test.shape)
# Out:
# ========= TEST SPLIT =========
# X_test .shape =  (356, 100)
# Y_test .shape =  (356,)

# %%
#Y_train

# %% [markdown]
# ### Reshape Inputs to be [samples, time_steps, Features] ==> reshape needed for LSTM tensor Architecture

# %% [markdown]
# #### tensor shape according to this example :
# #### Xtrain (1383 interior lists, 100 list inside each interior list, 1 each has one Value only) || Xtest (699,100,1)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
X_train.shape
# Out:
# (1726, 100, 1)

# %% [markdown]
# # MODELING

# %%
#Imports
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %% [markdown]
# ### Creating a Stacked LSTM model:

# %% [markdown]
# #### each layers is an identical LSTM layer with a final Dense layer || COST FUNCTION = Mean Squared Error

# %%
# - Units : Positive integer, dimensionality of the output space.
# - Return_sequences : Boolean. Whether to return the last output. in the output sequence,
# or the full sequence. Default: False.
# - input_shape : 100, 1

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(X_train.shape[1],X_train.shape[2])))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
#verification du modele
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 100, 50)           10400
#
#  lstm_10 (LSTM)              (None, 100, 50)           20200
#
#  lstm_11 (LSTM)              (None, 50)                20200
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
# - fit : Trains the model for a fixed number of epochs (iterations on a dataset).
# - object : Model to train.
# - X : Vector, matrix, or array of training data 
# - Y : Vector, matrix, or array of target (label) data (or list if the model has multiple outputs)
# - epochs : Number of epochs to train the model. Note that in conjunction with initial_epoch, epochs is to be understood as "final epoch". The model is not trained for a number of iterations given by epochs, but merely until the epoch of index epochs is reached.
# - validation_data	: Data on which to evaluate the loss and any model metrics at the end of each epoch. The model will not be trained on this data.
# - batch_size : Integer or NULL. Number of samples per gradient update. If unspecified, batch_size will default to 32.
# - verbose	: Verbosity mode (0 = silent, 1 = progress bar, 2 = one line per epoch).

# %%
Fitting = model.fit(X_train,Y_train,validation_data=(X_test,Y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 6s 121ms/step - loss: 0.0276 - val_loss: 4.4050e-04
# Epoch 2/100
# 27/27 [==============================] - 3s 95ms/step - loss: 0.0015 - val_loss: 7.0478e-05
# Epoch 3/100
# 27/27 [==============================] - 3s 95ms/step - loss: 0.0011 - val_loss: 7.4041e-05
# Epoch 4/100
# 27/27 [==============================] - 3s 95ms/step - loss: 0.0011 - val_loss: 9.3320e-05
# Epoch 5/100
# 27/27 [==============================] - 3s 94ms/step - loss: 0.0011 - val_loss: 5.1881e-05
# Epoch 6/100
# 27/27 [==============================] - 3s 96ms/step - loss: 0.0010 - val_loss: 5.8783e-05
# Epoch 7/100
# 27/27 [==============================] - 3s 95ms/step - loss: 9.3560e-04 - val_loss: 5.1768e-05
# Epoch 8/100
# 27/27 [==============================] - 3s 95ms/step - loss: 9.4077e-04 - val_loss: 4.7286e-05
# Epoch 9/100
# 27/27 [==============================] - 3s 94ms/step - loss: 9.2754e-04 - val_loss: 4.9235e-05
# Epoch 10/100
# 27/27 [==============================] - 3s 95ms/step - loss: 8.4526e-04 - val_loss: 5.9339e-05
# Epoch 11/100
# 27/27 [==============================] - 3s 94ms/step - loss: 8.7988e-04 - val_loss: 7.3143e-05
# Epoch 12/100
# 27/27 [==============================] - 3s 101ms/step - loss: 8.5504e-04 - val_loss: 5.2509e-05
# Epoch 13/100
# 27/27 [==============================] - 3s 106ms/step - loss: 7.1608e-04 - val_loss: 4.1716e-05
# Epoch 14/100
# 27/27 [==============================] - 3s 100ms/step - loss: 6.5837e-04 - val_loss: 6.0584e-05
# Epoch 15/100
# 27/27 [==============================] - 3s 97ms/step - loss: 6.2507e-04 - val_loss: 4.7001e-05
# Epoch 16/100
# 27/27 [==============================] - 3s 98ms/step - loss: 5.8807e-04 - val_loss: 3.8862e-05
# Epoch 17/100
# 27/27 [==============================] - 3s 98ms/step - loss: 6.5872e-04 - val_loss: 5.8960e-05
# Epoch 18/100
# 27/27 [==============================] - 3s 102ms/step - loss: 5.8927e-04 - val_loss: 3.6531e-05
# Epoch 19/100
# 27/27 [==============================] - 3s 97ms/step - loss: 5.2775e-04 - val_loss: 4.2123e-05
# Epoch 20/100
# 27/27 [==============================] - 3s 99ms/step - loss: 5.0369e-04 - val_loss: 4.0040e-05
# Epoch 21/100
# 27/27 [==============================] - 3s 98ms/step - loss: 4.9756e-04 - val_loss: 3.7487e-05
# Epoch 22/100
# 27/27 [==============================] - 3s 98ms/step - loss: 4.9675e-04 - val_loss: 3.4815e-05
# Epoch 23/100
# 27/27 [==============================] - 3s 97ms/step - loss: 5.1023e-04 - val_loss: 3.4042e-05
# Epoch 24/100
# 27/27 [==============================] - 3s 100ms/step - loss: 4.8724e-04 - val_loss: 3.6840e-05
# Epoch 25/100
# 27/27 [==============================] - 3s 98ms/step - loss: 4.4964e-04 - val_loss: 4.5932e-05
# Epoch 26/100
# 27/27 [==============================] - 3s 98ms/step - loss: 5.7629e-04 - val_loss: 1.0073e-04
# Epoch 27/100
# 27/27 [==============================] - 3s 99ms/step - loss: 4.6092e-04 - val_loss: 8.2027e-05
# Epoch 28/100
# 27/27 [==============================] - 3s 98ms/step - loss: 4.1432e-04 - val_loss: 4.3970e-05
# Epoch 29/100
# 27/27 [==============================] - 3s 98ms/step - loss: 3.8977e-04 - val_loss: 4.3513e-05
# Epoch 30/100
# 27/27 [==============================] - 3s 100ms/step - loss: 3.8946e-04 - val_loss: 2.9700e-05
# Epoch 31/100
# 27/27 [==============================] - 3s 98ms/step - loss: 3.7575e-04 - val_loss: 3.9717e-05
# Epoch 32/100
# 27/27 [==============================] - 3s 98ms/step - loss: 3.5011e-04 - val_loss: 3.0115e-05
# Epoch 33/100
# 27/27 [==============================] - 3s 98ms/step - loss: 3.3744e-04 - val_loss: 3.3643e-05
# Epoch 34/100
# 27/27 [==============================] - 3s 98ms/step - loss: 3.6927e-04 - val_loss: 3.1460e-05
# Epoch 35/100
# 27/27 [==============================] - 3s 99ms/step - loss: 3.6282e-04 - val_loss: 3.3260e-05
# Epoch 36/100
# 27/27 [==============================] - 3s 99ms/step - loss: 4.5640e-04 - val_loss: 3.8789e-05
# Epoch 37/100
# 27/27 [==============================] - 3s 98ms/step - loss: 5.5244e-04 - val_loss: 5.2776e-05
# Epoch 38/100
# 27/27 [==============================] - 3s 97ms/step - loss: 4.2634e-04 - val_loss: 3.0842e-05
# Epoch 39/100
# 27/27 [==============================] - 3s 98ms/step - loss: 3.8780e-04 - val_loss: 2.7926e-05
# Epoch 40/100
# 27/27 [==============================] - 3s 97ms/step - loss: 3.1869e-04 - val_loss: 4.5252e-05
# Epoch 41/100
# 27/27 [==============================] - 3s 98ms/step - loss: 3.1305e-04 - val_loss: 4.0072e-05
# Epoch 42/100
# 27/27 [==============================] - 3s 100ms/step - loss: 3.3389e-04 - val_loss: 2.7685e-05
# Epoch 43/100
# 27/27 [==============================] - 3s 98ms/step - loss: 3.5007e-04 - val_loss: 2.8317e-05
# Epoch 44/100
# 27/27 [==============================] - 3s 97ms/step - loss: 2.9864e-04 - val_loss: 3.4664e-05
# Epoch 45/100
# 27/27 [==============================] - 3s 99ms/step - loss: 2.8961e-04 - val_loss: 3.8773e-05
# Epoch 46/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.9962e-04 - val_loss: 2.6055e-05
# Epoch 47/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.8335e-04 - val_loss: 3.1673e-05
# Epoch 48/100
# 27/27 [==============================] - 3s 99ms/step - loss: 2.7761e-04 - val_loss: 2.4850e-05
# Epoch 49/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.9051e-04 - val_loss: 4.5709e-05
# Epoch 50/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.5367e-04 - val_loss: 2.7830e-05
# Epoch 51/100
# 27/27 [==============================] - 3s 97ms/step - loss: 2.5944e-04 - val_loss: 2.4256e-05
# Epoch 52/100
# 27/27 [==============================] - 3s 97ms/step - loss: 2.6622e-04 - val_loss: 3.2107e-05
# Epoch 53/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.8550e-04 - val_loss: 3.2288e-05
# Epoch 54/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.5796e-04 - val_loss: 2.8658e-05
# Epoch 55/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.3287e-04 - val_loss: 3.2854e-05
# Epoch 56/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.9341e-04 - val_loss: 3.6740e-05
# Epoch 57/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.7386e-04 - val_loss: 3.2853e-05
# Epoch 58/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.6495e-04 - val_loss: 2.6763e-05
# Epoch 59/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.1616e-04 - val_loss: 2.3385e-05
# Epoch 60/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.1428e-04 - val_loss: 2.7524e-05
# Epoch 61/100
# 27/27 [==============================] - 3s 101ms/step - loss: 2.3186e-04 - val_loss: 2.3376e-05
# Epoch 62/100
# 27/27 [==============================] - 3s 99ms/step - loss: 2.1089e-04 - val_loss: 2.8152e-05
# Epoch 63/100
# 27/27 [==============================] - 3s 98ms/step - loss: 2.6876e-04 - val_loss: 3.5993e-05
# Epoch 64/100
# 27/27 [==============================] - 3s 101ms/step - loss: 2.3745e-04 - val_loss: 2.5311e-05
# Epoch 65/100
# 27/27 [==============================] - 3s 97ms/step - loss: 2.4089e-04 - val_loss: 4.3396e-05
# Epoch 66/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.9128e-04 - val_loss: 2.3689e-05
# Epoch 67/100
# 27/27 [==============================] - 2s 93ms/step - loss: 2.2134e-04 - val_loss: 2.1062e-05
# Epoch 68/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.9493e-04 - val_loss: 3.0392e-05
# Epoch 69/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.7954e-04 - val_loss: 2.2373e-05
# Epoch 70/100
# 27/27 [==============================] - 2s 92ms/step - loss: 2.0068e-04 - val_loss: 2.3301e-05
# Epoch 71/100
# 27/27 [==============================] - 2s 92ms/step - loss: 2.6329e-04 - val_loss: 2.0089e-05
# Epoch 72/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.8324e-04 - val_loss: 2.4440e-05
# Epoch 73/100
# 27/27 [==============================] - 2s 93ms/step - loss: 1.7600e-04 - val_loss: 1.8542e-05
# Epoch 74/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.7688e-04 - val_loss: 1.9610e-05
# Epoch 75/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.8641e-04 - val_loss: 2.7374e-05
# Epoch 76/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.6396e-04 - val_loss: 1.8820e-05
# Epoch 77/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.5002e-04 - val_loss: 1.7739e-05
# Epoch 78/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.5945e-04 - val_loss: 1.8336e-05
# Epoch 79/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.4284e-04 - val_loss: 1.6925e-05
# Epoch 80/100
# 27/27 [==============================] - 3s 94ms/step - loss: 1.6170e-04 - val_loss: 5.9987e-05
# Epoch 81/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.6385e-04 - val_loss: 2.2847e-05
# Epoch 82/100
# 27/27 [==============================] - 2s 93ms/step - loss: 1.6005e-04 - val_loss: 2.3333e-05
# Epoch 83/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.4521e-04 - val_loss: 1.6868e-05
# Epoch 84/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.5878e-04 - val_loss: 1.7371e-05
# Epoch 85/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.3291e-04 - val_loss: 2.1954e-05
# Epoch 86/100
# 27/27 [==============================] - 2s 93ms/step - loss: 1.2212e-04 - val_loss: 2.2707e-05
# Epoch 87/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.2728e-04 - val_loss: 1.5826e-05
# Epoch 88/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.5717e-04 - val_loss: 1.7176e-05
# Epoch 89/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.4768e-04 - val_loss: 1.6130e-05
# Epoch 90/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.2281e-04 - val_loss: 1.8087e-05
# Epoch 91/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.6458e-04 - val_loss: 1.7355e-05
# Epoch 92/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.2003e-04 - val_loss: 1.8995e-05
# Epoch 93/100
# 27/27 [==============================] - 3s 93ms/step - loss: 1.1383e-04 - val_loss: 1.7790e-05
# Epoch 94/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.3757e-04 - val_loss: 1.5308e-05
# Epoch 95/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.3618e-04 - val_loss: 1.5032e-05
# Epoch 96/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.1970e-04 - val_loss: 1.8479e-05
# Epoch 97/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.1322e-04 - val_loss: 1.5276e-05
# Epoch 98/100
# 27/27 [==============================] - 2s 91ms/step - loss: 1.1015e-04 - val_loss: 1.5662e-05
# Epoch 99/100
# 27/27 [==============================] - 2s 93ms/step - loss: 1.1212e-04 - val_loss: 1.7325e-05
# Epoch 100/100
# 27/27 [==============================] - 2s 92ms/step - loss: 1.0292e-04 - val_loss: 1.7154e-05

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ##### We check the training accuracy compared to the validation accuracy to see if there's one of the following problems : underfitting or overfitting

# %%
#Fitting.history['loss']
#Fitting.history['accuracy']
#Fitting.history['val_loss']
#Fitting.history['val_accuracy']
plt.plot(Fitting.history['loss'])
plt.plot(Fitting.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['training loss','validation loss'], loc='upper right')
plt.show()

# %% [markdown]
# #### Following the above graph we can deduce that the loss of our model through training and then validation is minimal, Can be improved slightly through the addition of more epochs ( around 20 to 30)

# %% [markdown]
# ### Prediction and performance metrics check

# %%
#prediction
import tensorflow as tf
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##transform back to original form before scaling
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# #### Calculating RMSE ( root mean squared error / regression metrics)  performance metrics

# %%
#imports
import math
from sklearn.metrics import mean_squared_error #loss function

# %%
#train data RMSE
math.sqrt(mean_squared_error(Y_train,train_predict))
# Out:
# 12.50205616005504

# %%
#test data RMSE
math.sqrt(mean_squared_error(Y_test, test_predict))
# Out:
# 1.8570900113776412

# %% [markdown]
# #### Plotting our models training results

# %%
# shift train predictions for plotting
sns.set_style('whitegrid')
look_back=100
trainPredictPlot = np.empty_like(df_price)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(df_price)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df_price)-1, :] = test_predict
# plot baseline and predictions
plt.figure(figsize=(12,8))
plt.plot(scaler.inverse_transform(df_price))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)

plt.show()

# %% [markdown]
# # Prediction for next X days

# %%
#checking data length to pick data history range (100 days)
#Choose number of days for prediction
next_X_days = 20
length_test_data = len(test_data)

# %%
#taking 100 test data
x_input = test_data[length_test_data-100:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %% [markdown]
# #### converting 100 inputs to list  to use for the next_X_days prediction

# %%
temp_input = list(x_input)
temp_input=temp_input[0].tolist()

# %% [markdown]
# #### Demonstrating prediction for the next X days

# %%
# demonstrate prediction for next X days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<next_X_days):
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=1)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=1)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+
#  0.03029194 0.03015987 0.03002723 0.02989446 0.02976192 0.02962993
#  0.02949876 0.0293686  0.02923963 0.02911194]
# 1/1 [==============================] - 0s 18ms/step
# 13 day output [[0.02898563]]
# 14 day input [0.05782952 0.057454   0.057454   0.05858055 0.05670297 0.05632745
#  0.05595193 0.05595193 0.05595193 0.05632745 0.05933158 0.05933158
#  0.05933158 0.05632745 0.05444987 0.05444987 0.05444987 0.05444987
#  0.06421329 0.06383778 0.06271123 0.05933158 0.05933158 0.05632745
#  0.05632745 0.05632745 0.05482538 0.057454   0.05632745 0.05444987
#  0.05444987 0.05632745 0.05632745 0.05595193 0.05595193 0.057454
#  0.057454   0.05858055 0.05369884 0.05820503 0.05820503 0.05895606
#  0.06083365 0.06308674 0.06271123 0.05933158 0.05670297 0.05670297
#  0.057454   0.057454   0.05820503 0.06083365 0.06233571 0.06120916
#  0.06083365 0.06045813 0.057454   0.0552009  0.05369884 0.05670297
#  0.057454   0.01351859 0.02177995 0.02853924 0.03041682 0.03417199
#  0.03937505 0.03649691 0.03446302 0.03315281 0.03238406 0.0319783
#  0.03179042 0.03171638 0.03168924 0.03167071 0.03164204 0.03159637
#  0.03153325 0.03145494 0.03136442 0.03126444 0.03115712 0.03104404
#  0.03092629 0.03080468 0.03067988 0.03055246 0.03042298 0.03029194
#  0.03015987 0.03002723 0.02989446 0.02976192 0.02962993 0.02949876
#  0.0293686  0.02923963 0.02911194 0.02898563]
# 1/1 [==============================] - 0s 19ms/step
# 14 day output [[0.02886074]]
# 15 day input [0.057454   0.057454   0.05858055 0.05670297 0.05632745 0.05595193
#  0.05595193 0.05595193 0.05632745 0.05933158 0.05933158 0.05933158
#  0.05632745 0.05444987 0.05444987 0.05444987 0.05444987 0.06421329
#  0.06383778 0.06271123 0.05933158 0.05933158 0.05632745 0.05632745
#  0.05632745 0.05482538 0.057454   0.05632745 0.05444987 0.05444987
#  0.05632745 0.05632745 0.05595193 0.05595193 0.057454   0.057454
#  0.05858055 0.05369884 0.05820503 0.05820503 0.05895606 0.06083365
#  0.06308674 0.06271123 0.05933158 0.05670297 0.05670297 0.057454
#  0.057454   0.05820503 0.06083365 0.06233571 0.06120916 0.06083365
#  0.06045813 0.057454   0.0552009  0.05369884 0.05670297 0.057454
#  0.01351859 0.02177995 0.02853924 0.03041682 0.03417199 0.03937505
#  0.03649691 0.03446302 0.03315281 0.03238406 0.0319783  0.03179042
#  0.03171638 0.03168924 0.03167071 0.03164204 0.03159637 0.03153325
#  0.03145494 0.03136442 0.03126444 0.03115712 0.03104404 0.03092629
#  0.03080468 0.03067988 0.03055246 0.03042298 0.03029194 0.03015987
#  0.03002723 0.02989446 0.02976192 0.02962993 0.02949876 0.0293686
#  0.02923963 0.02911194 0.02898563 0.02886074]
# 1/1 [==============================] - 0s 19ms/step
# 15 day output [[0.0287373]]
# 16 day input [0.057454   0.05858055 0.05670297 0.05632745 0.05595193 0.05595193
#  0.05595193 0.05632745 0.05933158 0.05933158 0.05933158 0.05632745
#  0.05444987 0.05444987 0.05444987 0.05444987 0.06421329 0.06383778
#  0.06233571 0.06120916 0.06083365 0.06045813 0.057454   0.0552009
#  0.05369884 0.05670297 0.057454   0.01351859 0.02177995 0.02853924
#  0.03041682 0.03417199 0.03937505 0.03649691 0.03446302 0.03315281
#  0.03238406 0.0319783  0.03179042 0.03171638 0.03168924 0.03167071
#  0.03164204 0.03159637 0.03153325 0.03145494 0.03136442 0.03126444
#  0.03115712 0.03104404 0.03092629 0.03080468 0.03067988 0.03055246
#  0.03042298 0.03029194 0.03015987 0.03002723 0.02989446 0.02976192
#  0.02962993 0.02949876 0.0293686  0.02923963 0.02911194 0.02898563
#  0.02886074 0.0287373  0.02861531 0.02849477]
# 1/1 [==============================] - 0s 19ms/step
# 18 day output [[0.02837566]]
# 19 day input [0.05632745 0.05595193 0.05595193 0.05595193 0.05632745 0.05933158
#  0.05933158 0.05933158 0.05632745 0.05444987 0.05444987 0.05444987
#  0.05444987 0.06421329 0.06383778 0.06271123 0.05933158 0.05933158
#  0.05632745 0.05632745 0.05632745 0.05482538 0.057454   0.05632745
#  0.05444987 0.05444987 0.05632745 0.05632745 0.05595193 0.05595193
#  0.057454   0.057454   0.05858055 0.05369884 0.05820503 0.05820503
#  0.05895606 0.06083365 0.06308674 0.06271123 0.05933158 0.05670297
#  0.05670297 0.057454   0.057454   0.05820503 0.06083365 0.06233571
#  0.06120916 0.06083365 0.06045813 0.057454   0.0552009  0.05369884
#  0.05670297 0.057454   0.01351859 0.02177995 0.02853924 0.03041682
#  0.03417199 0.03937505 0.03649691 0.03446302 0.03315281 0.03238406
#  0.0319783  0.03179042 0.03171638 0.03168924 0.03167071 0.03164204
#  0.03159637 0.03153325 0.03145494 0.03136442 0.03126444 0.03115712
#  0.03104404 0.03092629 0.03080468 0.03067988 0.03055246 0.03042298
#  0.03029194 0.03015987 0.03002723 0.02989446 0.02976192 0.02962993
#  0.02949876 0.0293686  0.02923963 0.02911194 0.02898563 0.02886074
#  0.0287373  0.02861531 0.02849477 0.02837566]
# 1/1 [==============================] - 0s 19ms/step
# 19 day output [[0.02825796]]
# [[0.03067987971007824], [0.030552461743354797], [0.030422978103160858], [0.03029194287955761], [0.03015986829996109], [0.030027231201529503], [0.02989445999264717], [0.029761917889118195], [0.02962992712855339], [0.029498755931854248], [0.029368596151471138], [0.029239626601338387], [0.029111942276358604], [0.028985634446144104], [0.02886074222624302], [0.028737302869558334], [0.028615310788154602], [0.028494765982031822], [0.028375664725899696], [0.028257964178919792]]

# %%
#The arange ====> ([start,] stop[, step,][, dtype]) : Returns an array with evenly spaced elements as per the interval. The interval mentioned is half-opened i.e. [Start, Stop) 
day_new = np.arange(1,101)
day_pred_range = 101 + next_X_days
day_pred=np.arange(101,day_pred_range)

# %%
df_price.shape
# Out:
# (2284, 1)

# %% [markdown]
# ### Plotting next_X_days prediction with the last  100 days before

# %%
# import matplotlib.pyplot as plt ==> imported top
plot_size = df_price.shape[0]-100
plt.figure(figsize=(12,8))
plt.plot(day_new,scaler.inverse_transform(df_price[plot_size:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))
